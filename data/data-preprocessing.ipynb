# %% [markdown]
# ## Converts the heat and temperature data to csv format

# %%
import pandas as pd
import datetime 
import string

# %%
# read column headings
with open ('/Users/stewarta/repos/iot-htsensor/data/columns.txt') as f:
    cols = f.readlines()
    
cols = [ln.strip() for ln in cols] 
print(cols)
# Out:
# ['timestamp', 'Start Symbol', 'Zustand', 'Zeitstempel', 'Temp1', 'Temp2', 'Temp3', 'Temp4', 'Temp5', 'Temp6', 'Temp7', 'Temp8', 'Humi1', 'Humi2', 'Humi3', 'Humi4', 'Humi5', 'Humi6', 'Humi7', 'Humi8', 'Temperatur Kombisensor', 'Humid Kombisensor', 'Windgeschwindigkeit', 'Niederschlag', 'Rain', 'Stop Symbol']

# %%
# read data from file
df = pd.read_csv('/Users/stewarta/Documents/DATA/htsensor/raw.data', sep = ';',decimal=',', names=cols)
df.head()
# Out:
#               timestamp Start Symbol  Zustand  Zeitstempel  Temp1  Temp2  \
# 0  2013-04-14 07:44:23            $1        1          NaN   10.1   19.6
# 1  2013-04-14 07:44:30            $1        1          NaN   10.1   19.6
# 2  2013-04-14 07:45:37            $1        1          NaN   10.1   19.6
# 3  2013-04-14 07:46:03            $1        1          NaN   10.1   19.6
# 4  2013-04-14 07:46:19            $1        1          NaN   10.1   19.6
#
#    Temp3  Temp4  Temp5  Temp6     ...       Humi5  Humi6  Humi7  Humi8  \
# 0   23.0   20.2    NaN    NaN     ...         NaN    NaN    NaN    NaN
# 1   23.0   20.2    NaN    NaN     ...         NaN    NaN    NaN    NaN
# 2   23.0   20.2    NaN    NaN     ...         NaN    NaN    NaN    NaN
# 3   23.0   20.2    NaN    NaN     ...         NaN    NaN    NaN    NaN
# 4   23.0   20.2    NaN    NaN     ...         NaN    NaN    NaN    NaN
#
#    Temperatur Kombisensor  Humid Kombisensor  Windgeschwindigkeit  \
# 0                     NaN                NaN                  NaN
# 1                     NaN                NaN                  NaN
# 2                     NaN                NaN                  NaN
# 3                     NaN                NaN                  NaN
# 4                     NaN                NaN                  NaN
#
#    Niederschlag  Rain  Stop Symbol
# 0           NaN   NaN            0
# 1           NaN   NaN            0
# 2           NaN   NaN            0
# 3           NaN   NaN            0
# 4           NaN   NaN            0
#
# [5 rows x 26 columns]

# %%
# parse date and insert as new column
df.insert(1, 'datetime', pd.to_datetime(df.timestamp, errors='coerce')) # If ‘coerce’, then invalid parsing will be set as NaT

# %%
df.head()
# Out:
#                                 timestamp            datetime Start Symbol  \
# datetime
# 2013-04-14 07:44:23  2013-04-14 07:44:23  2013-04-14 07:44:23           $1
# 2013-04-14 07:44:30  2013-04-14 07:44:30  2013-04-14 07:44:30           $1
# 2013-04-14 07:45:37  2013-04-14 07:45:37  2013-04-14 07:45:37           $1
# 2013-04-14 07:46:03  2013-04-14 07:46:03  2013-04-14 07:46:03           $1
# 2013-04-14 07:46:19  2013-04-14 07:46:19  2013-04-14 07:46:19           $1
#
#                      Zustand  Zeitstempel  Temp1  Temp2  Temp3  Temp4  Temp5  \
# datetime
# 2013-04-14 07:44:23        1          NaN   10.1   19.6   23.0   20.2    NaN
# 2013-04-14 07:44:30        1          NaN   10.1   19.6   23.0   20.2    NaN
# 2013-04-14 07:45:37        1          NaN   10.1   19.6   23.0   20.2    NaN
# 2013-04-14 07:46:03        1          NaN   10.1   19.6   23.0   20.2    NaN
# 2013-04-14 07:46:19        1          NaN   10.1   19.6   23.0   20.2    NaN
#
#                         ...       Humi5  Humi6  Humi7  Humi8  \
# datetime                ...
# 2013-04-14 07:44:23     ...         NaN    NaN    NaN    NaN
# 2013-04-14 07:44:30     ...         NaN    NaN    NaN    NaN
# 2013-04-14 07:45:37     ...         NaN    NaN    NaN    NaN
# 2013-04-14 07:46:03     ...         NaN    NaN    NaN    NaN
# 2013-04-14 07:46:19     ...         NaN    NaN    NaN    NaN
#
#                      Temperatur Kombisensor  Humid Kombisensor  \
# datetime
# 2013-04-14 07:44:23                     NaN                NaN
# 2013-04-14 07:44:30                     NaN                NaN
# 2013-04-14 07:45:37                     NaN                NaN
# 2013-04-14 07:46:03                     NaN                NaN
# 2013-04-14 07:46:19                     NaN                NaN
#
#                      Windgeschwindigkeit  Niederschlag  Rain  Stop Symbol
# datetime
# 2013-04-14 07:44:23                  NaN           NaN   NaN            0
# 2013-04-14 07:44:30                  NaN           NaN   NaN            0
# 2013-04-14 07:45:37                  NaN           NaN   NaN            0
# 2013-04-14 07:46:03                  NaN           NaN   NaN            0
# 2013-04-14 07:46:19                  NaN           NaN   NaN            0
#
# [5 rows x 27 columns]

# %%
df.set_index('datetime', inplace=True)

# %%
df.head()
# Out:
#                                 timestamp            datetime Start Symbol  \
# datetime
# 2013-04-14 07:44:23  2013-04-14 07:44:23  2013-04-14 07:44:23           $1
# 2013-04-14 07:44:30  2013-04-14 07:44:30  2013-04-14 07:44:30           $1
# 2013-04-14 07:45:37  2013-04-14 07:45:37  2013-04-14 07:45:37           $1
# 2013-04-14 07:46:03  2013-04-14 07:46:03  2013-04-14 07:46:03           $1
# 2013-04-14 07:46:19  2013-04-14 07:46:19  2013-04-14 07:46:19           $1
#
#                      Zustand  Zeitstempel  Temp1  Temp2  Temp3  Temp4  Temp5  \
# datetime
# 2013-04-14 07:44:23        1          NaN   10.1   19.6   23.0   20.2    NaN
# 2013-04-14 07:44:30        1          NaN   10.1   19.6   23.0   20.2    NaN
# 2013-04-14 07:45:37        1          NaN   10.1   19.6   23.0   20.2    NaN
# 2013-04-14 07:46:03        1          NaN   10.1   19.6   23.0   20.2    NaN
# 2013-04-14 07:46:19        1          NaN   10.1   19.6   23.0   20.2    NaN
#
#                         ...       Humi5  Humi6  Humi7  Humi8  \
# datetime                ...
# 2013-04-14 07:44:23     ...         NaN    NaN    NaN    NaN
# 2013-04-14 07:44:30     ...         NaN    NaN    NaN    NaN
# 2013-04-14 07:45:37     ...         NaN    NaN    NaN    NaN
# 2013-04-14 07:46:03     ...         NaN    NaN    NaN    NaN
# 2013-04-14 07:46:19     ...         NaN    NaN    NaN    NaN
#
#                      Temperatur Kombisensor  Humid Kombisensor  \
# datetime
# 2013-04-14 07:44:23                     NaN                NaN
# 2013-04-14 07:44:30                     NaN                NaN
# 2013-04-14 07:45:37                     NaN                NaN
# 2013-04-14 07:46:03                     NaN                NaN
# 2013-04-14 07:46:19                     NaN                NaN
#
#                      Windgeschwindigkeit  Niederschlag  Rain  Stop Symbol
# datetime
# 2013-04-14 07:44:23                  NaN           NaN   NaN            0
# 2013-04-14 07:44:30                  NaN           NaN   NaN            0
# 2013-04-14 07:45:37                  NaN           NaN   NaN            0
# 2013-04-14 07:46:03                  NaN           NaN   NaN            0
# 2013-04-14 07:46:19                  NaN           NaN   NaN            0
#
# [5 rows x 27 columns]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1093567 entries, 2013-04-14 07:44:23 to 2016-02-09 22:41:09
# Data columns (total 27 columns):
# timestamp                 1093567 non-null object
# datetime                  1092265 non-null datetime64[ns]
# Start Symbol              1093567 non-null object
# Zustand                   1093567 non-null int64
# Zeitstempel               0 non-null float64
# Temp1                     1089409 non-null float64
# Temp2                     1029527 non-null float64
# Temp3                     787389 non-null float64
# Temp4                     679930 non-null float64
# Temp5                     14 non-null float64
# Temp6                     28 non-null float64
# Temp7                     0 non-null float64
# Temp8                     893742 non-null float64
# Humi1                     1089403 non-null float64
# Humi2                     1029531 non-null float64
# Humi3                     787386 non-null float64
# Humi4                     679935 non-null float64
# Humi5                     60 non-null float64
# Humi6                     87 non-null float64
# Humi7                     7 non-null float64
# Humi8                     0 non-null float64
# Temperatur Kombisensor    0 non-null float64
# Humid Kombisensor         0 non-null float64
# Windgeschwindigkeit       0 non-null float64
# Niederschlag              14 non-null float64
# Rain                      14 non-null float64
# Stop Symbol               1093567 non-null int64
# dtypes: datetime64[ns](1), float64(22), int64(2), object(2)
# memory usage: 233.6+ MB

# %%
rs = df['Temp1'].resample('H').mean()

# %%
type(rs)
# Out:
# pandas.core.series.Series

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1093567 entries, 0 to 1093566
# Data columns (total 27 columns):
# timestamp                 1093567 non-null object
# Start Symbol              1093567 non-null object
# Zustand                   1093567 non-null int64
# Zeitstempel               0 non-null float64
# Temp1                     1089409 non-null object
# Temp2                     1029527 non-null object
# Temp3                     787389 non-null object
# Temp4                     679930 non-null object
# Temp5                     14 non-null object
# Temp6                     28 non-null object
# Temp7                     0 non-null float64
# Temp8                     893742 non-null object
# Humi1                     1089403 non-null float64
# Humi2                     1029531 non-null float64
# Humi3                     787386 non-null float64
# Humi4                     679935 non-null float64
# Humi5                     60 non-null float64
# Humi6                     87 non-null float64
# Humi7                     7 non-null float64
# Humi8                     0 non-null float64
# Temperatur Kombisensor    0 non-null float64
# Humid Kombisensor         0 non-null float64
# Windgeschwindigkeit       0 non-null float64
# Niederschlag              14 non-null float64
# Rain                      14 non-null float64
# Stop Symbol               1093567 non-null int64
# datetime                  1092265 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(15), int64(2), object(9)
# memory usage: 225.3+ MB

# %%
# drop columns with no data
empty = [col for col in df.columns if df[col].isnull().all()]
print(empty)
# Out:
# ['Zustand', 'Temp6', 'Humi7', 'Humi8', 'Temperatur Kombisensor', 'Humid Kombisensor', 'Stop Symbol']

# %%
1089409 + 787389
# Out:
# 1876798
